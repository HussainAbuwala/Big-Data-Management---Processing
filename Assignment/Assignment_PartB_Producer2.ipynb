# %%
# import statements
from time import sleep
from json import dumps
from kafka import KafkaProducer
import random
import datetime as dt

import csv
import random
import pymongo
from pymongo import MongoClient
from datetime import datetime
from datetime import timedelta  


# SEND MESSAGE TO KAFKA SERVER
def publish_message(producer_instance, topic_name, key, value):
    try:
        key_bytes = bytes(key, encoding='utf-8')
        value_bytes = bytes(value, encoding='utf-8')
        producer_instance.send(topic_name, key=key_bytes, value=value_bytes)
        producer_instance.flush()
        print('Message published successfully. Data: ' + str(value))
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))

# CONNECT TO KAFKA
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=['localhost:9092'],
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer
    

#READ DATA
def read_data(filename):
    
    data = []
    with open(filename) as csvfile:
         i = 0
         for row in csvfile:
            if(i == 0):
                i+=1
                continue
            row = row.strip()
            data.append(row)
    
    return data

# RANDOM WITH REPLACEMENT
def get_random(data):
    return random.choice(data)

    
if __name__ == '__main__':
       
    #TOPIC IS CLIMATE
    #CREATE DATA TO SEND
    #ADD EVENT DATETIME
    #SEND KEY
    #SEND DATA EVERY 2 SECONDS    
        
    
    topic = 'climate'
    
    print('Publishing records..')
    producer = connect_kafka_producer()
    climate_data = read_data("hotspot_AQUA_streaming.csv")
    
    
    for e in range(50):
        #data = str(dt.datetime.now().strftime("%X")) + ', ' + str(random.randrange(0,100))
        
        data_to_send = get_random(climate_data)
        data_to_send = data_to_send + "," + dt.datetime.now().strftime("%d/%m/%Y-%H:%M:%S")
        publish_message(producer, topic, 'producer_2', data_to_send)
        sleep(2)
# Out:
# Publishing records..
# Message published successfully. Data: -36.2367,141.3998,65,42,11/06/2020-14:33:51
# Message published successfully. Data: -37.9277,143.477,66,55,11/06/2020-14:33:53
# Message published successfully. Data: -36.6248,142.2042,71,46,11/06/2020-14:33:55
# Message published successfully. Data: -37.886,147.207,50,28,11/06/2020-14:33:57
# Message published successfully. Data: -37.9774,141.2029,67,50,11/06/2020-14:33:59
# Message published successfully. Data: -36.6217,145.2537,75,49,11/06/2020-14:34:01
# Message published successfully. Data: -36.8009,142.7259,95,76,11/06/2020-14:34:03
# Message published successfully. Data: -36.9826,143.6671,78,51,11/06/2020-14:34:05
# Message published successfully. Data: -37.7931,148.385,64,58,11/06/2020-14:34:07
# Message published successfully. Data: -38.2234,143.9549,56,39,11/06/2020-14:34:09
# Message published successfully. Data: -37.4671,145.9962,93,73,11/06/2020-14:34:11
# Message published successfully. Data: -36.4274,142.1944,71,46,11/06/2020-14:34:13
# Message published successfully. Data: -37.7619,142.8294,71,46,11/06/2020-14:34:15
# Message published successfully. Data: -36.085,145.9096,64,42,11/06/2020-14:34:17
# Message published successfully. Data: -37.4323,147.6583,95,76,11/06/2020-14:34:19
# Message published successfully. Data: -36.5754,142.2926,100,111,11/06/2020-14:34:21
# Message published successfully. Data: -36.9827,141.4064,62,41,11/06/2020-14:34:23
# Message published successfully. Data: -38.0652,142.9781,81,54,11/06/2020-14:34:25
# Message published successfully. Data: -36.4133,141.0286,52,47,11/06/2020-14:34:27
# Message published successfully. Data: -37.569,148.024,87,60,11/06/2020-14:34:29
# Message published successfully. Data: -36.1858,143.885,55,39,11/06/2020-14:34:31
# Message published successfully. Data: -36.4518,144.7752,100,97,11/06/2020-14:34:33
# Message published successfully. Data: -37.7756,143.1388,90,67,11/06/2020-14:34:35
# Message published successfully. Data: -36.4169,144.2994,97,81,11/06/2020-14:34:37
# Message published successfully. Data: -36.3374,141.041,76,49,11/06/2020-14:34:39
# Message published successfully. Data: -37.6345,143.1335,57,39,11/06/2020-14:34:41
# Message published successfully. Data: -36.8202,141.9362,76,50,11/06/2020-14:34:43
# Message published successfully. Data: -36.902,141.9965,86,60,11/06/2020-14:34:45
# Message published successfully. Data: -37.7851,141.4593,52,38,11/06/2020-14:34:47
# Message published successfully. Data: -36.343,142.1986,100,123,11/06/2020-14:34:49
# Message published successfully. Data: -36.4925,142.2657,74,48,11/06/2020-14:34:51
# Message published successfully. Data: -37.333,143.534,88,58,11/06/2020-14:34:53
# Message published successfully. Data: -38.0494,143.9141,63,58,11/06/2020-14:34:55
# Message published successfully. Data: -36.1021,146.6853,52,42,11/06/2020-14:34:57
# Message published successfully. Data: -37.3654,143.8156,65,42,11/06/2020-14:34:59
# Message published successfully. Data: -36.1722,145.9429,74,48,11/06/2020-14:35:01
# Message published successfully. Data: -36.7667,141.1177,68,44,11/06/2020-14:35:03
# Message published successfully. Data: -36.6986,142.7259,86,72,11/06/2020-14:35:05
# Message published successfully. Data: -37.293,141.245,99,85,11/06/2020-14:35:07
# Message published successfully. Data: -37.7505,143.1601,78,51,11/06/2020-14:35:09
# Message published successfully. Data: -36.8083,142.0219,67,44,11/06/2020-14:35:11
# Message published successfully. Data: -38.0132,146.5269,88,73,11/06/2020-14:35:13
# Message published successfully. Data: -37.2017,143.8117,88,64,11/06/2020-14:35:15
# Message published successfully. Data: -38.2003,146.8378,100,58,11/06/2020-14:35:17
# Message published successfully. Data: -36.346,143.631,71,49,11/06/2020-14:35:19
# Message published successfully. Data: -36.0047,146.4774,64,42,11/06/2020-14:35:21
# Message published successfully. Data: -36.1586,145.6666,99,85,11/06/2020-14:35:23
# Message published successfully. Data: -36.0831,146.5514,76,49,11/06/2020-14:35:25
# Message published successfully. Data: -36.5911,144.4764,72,46,11/06/2020-14:35:27
# Message published successfully. Data: -35.8125,142.1286,75,109,11/06/2020-14:35:29

# %% [markdown]
# # Command to list topics in kafka server
#
# sudo bin/kafka-topics.sh --list --zookeeper localhost:2181

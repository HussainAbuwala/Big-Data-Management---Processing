# %%
# import statements
from time import sleep
from json import dumps
from kafka import KafkaProducer
import random
import datetime as dt

import csv
import random
import pymongo
from pymongo import MongoClient
from datetime import datetime
from datetime import timedelta  

#SEND MESSAGE TO SERVER
def publish_message(producer_instance, topic_name, key, value):
    try:
        key_bytes = bytes(key, encoding='utf-8')
        value_bytes = bytes(value, encoding='utf-8')
        producer_instance.send(topic_name, key=key_bytes, value=value_bytes)
        producer_instance.flush()
        print('Message published successfully. Data: ' + str(value))
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))

#CONNECT TO KAFKA SERVER
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=['localhost:9092'],
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer
    

#READ DATA FROM CSV FILE
def read_data(filename):
    
    data = []
    with open(filename) as csvfile:
         i = 0
         for row in csvfile:
            if(i == 0):
                i+=1
                continue
            row = row.strip()
            data.append(row)
    
    return data

#RANDOM WITH REPLACEMENT
def get_random(data):
    return random.choice(data)

    
if __name__ == '__main__':
    
    #TOPIC IS CLIMATE
    #CREATE DATA TO SEND
    #ADD EVENT DATETIME
    #SEND KEY
    # SEND DATA EVERY 2 SECONDS
    
    topic = 'climate'
    
    print('Publishing records..')
    producer = connect_kafka_producer()
    climate_data = read_data("hotspot_TERRA_streaming.csv")
    
    for e in range(50):
        #data = str(dt.datetime.now().strftime("%X")) + ', ' + str(random.randrange(0,100))
        
        data_to_send = get_random(climate_data)
        data_to_send = data_to_send + "," + dt.datetime.now().strftime("%d/%m/%Y-%H:%M:%S")
        publish_message(producer, topic, 'producer_3', data_to_send)
        sleep(2)
# Out:
# Publishing records..
# Message published successfully. Data: -36.6995,142.9146,82,56,11/06/2020-14:33:47
# Message published successfully. Data: -35.6778,143.1774,97,45,11/06/2020-14:33:49
# Message published successfully. Data: -36.587,142.87,65,42,11/06/2020-14:33:51
# Message published successfully. Data: -37.3785,145.6226,77,50,11/06/2020-14:33:53
# Message published successfully. Data: -34.7979,141.5966,77,50,11/06/2020-14:33:55
# Message published successfully. Data: -37.9913,143.5272,64,42,11/06/2020-14:33:57
# Message published successfully. Data: -36.2972,145.9588,84,57,11/06/2020-14:33:59
# Message published successfully. Data: -36.0667,146.0308,85,59,11/06/2020-14:34:01
# Message published successfully. Data: -38.1693,143.0466,93,73,11/06/2020-14:34:03
# Message published successfully. Data: -38.038,142.986,65,40,11/06/2020-14:34:05
# Message published successfully. Data: -37.087,145.37,64,33,11/06/2020-14:34:07
# Message published successfully. Data: -36.608,142.7127,84,57,11/06/2020-14:34:09
# Message published successfully. Data: -36.3484,141.4983,61,41,11/06/2020-14:34:11
# Message published successfully. Data: -38.3849,146.6745,55,39,11/06/2020-14:34:13
# Message published successfully. Data: -36.9357,142.0353,75,48,11/06/2020-14:34:15
# Message published successfully. Data: -37.9318,143.2083,69,44,11/06/2020-14:34:17
# Message published successfully. Data: -37.8468,142.8775,84,58,11/06/2020-14:34:19
# Message published successfully. Data: -37.7269,143.0087,100,114,11/06/2020-14:34:21
# Message published successfully. Data: -37.4224,147.0511,100,113,11/06/2020-14:34:23
# Message published successfully. Data: -37.34,149.3668,67,74,11/06/2020-14:34:25
# Message published successfully. Data: -36.2669,143.1906,61,45,11/06/2020-14:34:27
# Message published successfully. Data: -37.7074,143.3065,82,56,11/06/2020-14:34:29
# Message published successfully. Data: -36.4373,143.6328,67,43,11/06/2020-14:34:31
# Message published successfully. Data: -35.889,145.614,82,56,11/06/2020-14:34:33
# Message published successfully. Data: -36.8009,142.7259,95,76,11/06/2020-14:34:35
# Message published successfully. Data: -36.937,142.1176,61,50,11/06/2020-14:34:37
# Message published successfully. Data: -36.8298,143.4483,96,79,11/06/2020-14:34:39
# Message published successfully. Data: -37.425,148.107,100,50,11/06/2020-14:34:41
# Message published successfully. Data: -37.453,148.099,78,44,11/06/2020-14:34:43
# Message published successfully. Data: -36.3634,144.3871,72,47,11/06/2020-14:34:45
# Message published successfully. Data: -36.7124,143.8381,71,46,11/06/2020-14:34:47
# Message published successfully. Data: -37.1815,146.7777,71,46,11/06/2020-14:34:49
# Message published successfully. Data: -36.4737,142.2474,74,55,11/06/2020-14:34:51
# Message published successfully. Data: -36.1462,143.5438,74,51,11/06/2020-14:34:53
# Message published successfully. Data: -37.5043,146.3299,100,93,11/06/2020-14:34:56
# Message published successfully. Data: -36.291,146.159,56,40,11/06/2020-14:34:58
# Message published successfully. Data: -36.4286,141.1567,99,84,11/06/2020-14:35:00
# Message published successfully. Data: -36.3971,142.6444,69,44,11/06/2020-14:35:02
# Message published successfully. Data: -37.227,141.146,54,31,11/06/2020-14:35:04
# Message published successfully. Data: -36.6299,142.4234,66,71,11/06/2020-14:35:06
# Message published successfully. Data: -37.6784,146.1432,93,44,11/06/2020-14:35:08
# Message published successfully. Data: -37.9004,141.0921,68,44,11/06/2020-14:35:10
# Message published successfully. Data: -36.0156,143.2188,66,43,11/06/2020-14:35:12
# Message published successfully. Data: -36.807,144.3933,63,41,11/06/2020-14:35:14
# Message published successfully. Data: -36.3757,145.5589,65,43,11/06/2020-14:35:16
# Message published successfully. Data: -37.8289,145.9315,75,49,11/06/2020-14:35:18
# Message published successfully. Data: -36.993,141.2317,67,43,11/06/2020-14:35:20
# Message published successfully. Data: -37.6531,147.8262,71,45,11/06/2020-14:35:22
# Message published successfully. Data: -38.4068,147.0682,69,44,11/06/2020-14:35:24
# Message published successfully. Data: -38.1403,144.2187,84,58,11/06/2020-14:35:26

# %% [markdown]
# # Command to list topics in kafka server
#
# sudo bin/kafka-topics.sh --list --zookeeper localhost:2181
